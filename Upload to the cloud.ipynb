# %%
# !pip install psycopg2
import psycopg2 as ps
import pandas as pd
# Out:
# Requirement already satisfied: psycopg2 in c:\users\ariel\appdata\local\programs\python\python310\lib\site-packages (2.9.2)

# %% [markdown]
# Importing Dataframe to Database
# 1. Connect to the database
# 2. Create table
# 3. Import dataframe

# %% [markdown]
# 1. Connecting to database

# %%
def connect_2_database(host_name, dbname, username, password, port):
    try:
        conn = ps.connect(host=host_name, database=dbname, user=username, password=password, port=port)
    except ps.OperationalError as e:
        raise e
    else:
        print("Connected")
        return conn

# %% [markdown]
# 2. Creating Table

# %%
#write out the SQL command line to create a table
def create_table(curr):
    create_table_command = ("""CREATE TABLE IF NOT EXISTS VIDEOS (
        VIDEO_ID VARCHAR(255) PRIMARY KEY,
        VIDEO_TITLE TEXT NOT NULL,
        UPLOAD_DATE DATE NOT NULL DEFAULT CURRENT_DATE,
        VIEW_COUNT INTEGER NOT NULL,
        LIKE_COUNT INTEGER NOT NULL,
        DISLIKE_COUNT INTEGER NOT NULL,
        COMMENT_COUNT INTEGER NOT NULL
    )   """)
    curr.execute(create_table_command)

# %%
#check to see if video exists
def check_if_video_exists(curr,video_id):
    query = ("""SELECT video_id FROM VIDEOS WHERE video_id = %s""")
    curr.execute(query, (video_id,))

    return curr.fetchone() is not None

# %%
#update row function
def update_row(curr, video_title, view_count, like_count, dislike_count, comment_count, video_id):
    query = ("""UPDATE videos
                SET video_title = %s,
                view_count = %s,
                like_count = %s,
                dislike_count = %s,
                comment_count = = %s
                WHERE video_id = %s;""")

                # all the columns in the pandas dateframe               
    columns = (video_title, view_count, like_count, dislike_count, comment_count, video_id)
    curr.execute(query,columns)

# %%
#updating the database
#handling data for scalability
def update_db(curr, df):
    temp_df = pd.DataFrame(columns=['video_id','video_title', 'upload_date', 'view_count', 'like_count', 'dislike_count', 'comment_count'])

    #check to see if video exists
    for i, row in df.iterrows():
        #if video already exists then we will update
        if check_if_video_exists(curr,row['video_id']):
            update_row(curr,row['video_title'], row['view_count'], row['like_count'], row['dislike_count'], row['comment_count'], row['video_id']) #update SQL command
        #else the video doesnt exist so we will append to the db table    
        else:
            temp_df = temp_df.append(row) #insert command
    return temp_df

# %%
#write insert command
def insert_into_table(curr,video_id,video_title,upload_date,view_count,like_count,dislike_count,comment_count):
    insert_to_db = ("""INSERT INTO videos (video_id, video_title, upload_date, view_count, like_count, dislike_count, comment_count)
                    VALUES (%s,%s, %s, %s, %s, %s, %s); """)

    rows_to_insert = (video_id,video_title,upload_date,view_count,like_count,dislike_count,comment_count)
    curr.execute(insert_to_db, rows_to_insert)

# %%
def append_data_to_db(curr, df):
    for i, row in df.iterrows():
        insert_into_table(curr, row['video_id'], row['video_title'],row['upload_date'],row['view_count'],row['like_count'], row['dislike_count'],row['comment_count'])

# %%
df = pd.read_csv("Youtube_Data.csv", index_col=0)
df.head()
# Out:
#       video_id                                        video_title upload_date  \
# 0  rUICJO4qwms  How To Grow Your YouTube Channel - 5 Tips For ...  2021-10-26
# 1  wbBY2tTqXDA                            Relations and Functions  2021-08-25
# 2  dHjWVlfNraM              Kinematics In One Dimension - Physics  2021-05-31
# 3  OqsOIp5UuME                               Resonance Structures  2021-05-24
# 4  zRKZ0-kOUZM  Geometric Series and Geometric Sequences - Bas...  2021-05-16
#
#    view_count  like_count  dislike_count  comment_count
# 0       93860        2879             34            447
# 1       67543        1863             21            128
# 2      212740        4013             57            161
# 3      101855        1500             34             67
# 4      175094        3125             77            109

# %%
host_name = 'yt-database.canwxyhiqzan.us-east-2.rds.amazonaws.com'
dbname = ''
port = '5432'
username = 'postgres'
password = 'Mmaxierucky100'
conn = None 

conn = connect_2_database(host_name, dbname, username, password, port)
# Out:
# Connected

# %%
# this cursor function lets us execute SQL commands in python
curr = conn.cursor()

# %%
create_table(curr)

# %%
#We save the results of update_db() to a variable beacuse it'll return a df
# with the new videos we'll have to insert into our database.  
new_videos_df = update_db(curr, df)
# Out:
# 0
# video_id                                               rUICJO4qwms
# video_title      How To Grow Your YouTube Channel - 5 Tips For ...
# upload_date                                             2021-10-26
# view_count                                                   93860
# like_count                                                    2879
# dislike_count                                                   34
# comment_count                                                  447
# Name: 0, dtype: object
# 1
# video_id                     wbBY2tTqXDA
# video_title      Relations and Functions
# upload_date                   2021-08-25
# view_count                         67543
# like_count                          1863
# dislike_count                         21
# comment_count                        128
# Name: 1, dtype: object
# 2
# video_id                                   dHjWVlfNraM
# video_title      Kinematics In One Dimension - Physics
# upload_date                                 2021-05-31
# view_count                                      212740
# like_count                                        4013
# dislike_count                                       57
# comment_count                                      161
# Name: 2, dtype: object
# 3
# video_id                  OqsOIp5UuME
# video_title      Resonance Structures
# upload_date                2021-05-24
# view_count                     101855
# like_count                       1500
# dislike_count                      34
# comment_count                      67
# Name: 3, dtype: object
# 4
# video_id                                               zRKZ0-kOUZM
# video_title      Geometric Series and Geometric Sequences - Bas...
# upload_date                                             2021-05-16
# view_count                                                  175094
# like_count                                                    3125
# dislike_count                                                   77
# comment_count                                                  109
# Name: 4, dtype: object
# 5
# video_id                                               XZJdyPkCxuE
# video_title      Arithmetic Sequences and Arithmetic Series - B...
# upload_date                                             2021-05-13
# view_count                                                  287783
# like_count                                                    5852
# dislike_count                                                   87
# comment_count                                                  192
# Name: 5, dtype: object
# 6
# video_id                                               J6TnZxUUzqU
# video_title      Complex Numbers In Polar - De Moivre&#39;s The...
# upload_date                                             2021-05-10
# view_count                                                  111724
# like_count                                                    1938
# dislike_count                                                   38
# comment_count                                                  110
# Name: 6, dtype: object
# 7
# video_id                                               KYgmOTLbuqE
# video_title      Finding The Focus and Directrix of a Parabola ...
# upload_date                                             2021-05-02
# view_count                                                  203797
# like_count                                                    3381
# dislike_count                                                   67
# comment_count                                                  144
# Name: 7, dtype: object
# 8
# video_id                                               OPSCKXXvWiM
# video_title      Writing Equations of Ellipses In Standard Form...
# upload_date                                             2021-04-29
# view_count                                                  149027
# like_count                                                    2595
# dislike_count                                                   52
# comment_count                                                   97
# Name: 8, dtype: object
# 9
# video_id                          QKkdYW77xNI
# video_title      Partial Fraction Decomposion
# upload_date                        2021-04-23
# view_count                             272121
# like_count                               4359
# dislike_count                              97
# comment_count                             133
# Name: 9, dtype: object
# 10
# video_id             xaCPDMEkbig
# video_title      Antiderivatives
# upload_date           2021-04-21
# view_count                138979
# like_count                  2956
# dislike_count                 25
# comment_count                127
# Name: 10, dtype: object
# 11
# video_id                                   sdYdnpYn-1o
# video_title      How To Integrate Using U-Substitution
# upload_date                                 2021-04-19
# view_count                                      342628
# like_count                                        5881
# dislike_count                                       72
# comment_count                                      256
# Name: 11, dtype: object
# 12
# video_id                          jO4lwddfeDA
# video_title      How To Graph Polar Equations
# upload_date                        2021-04-17
# view_count                              84510
# like_count                               1612
# dislike_count                              28
# comment_count                              68
# Name: 12, dtype: object
# 13
# video_id                          Tmdrjs9xufc
# video_title      Transformations of Functions
# upload_date                        2021-04-16
# view_count                             104124
# like_count                               2279
# dislike_count                              35
# comment_count                              76
# Name: 13, dtype: object
# 14
# video_id                         CwkhvFlNFp0
# video_title      Physics 1 Final Exam Review
# upload_date                       2021-04-07
# view_count                            121891
# like_count                              3196
# dislike_count                             22
# comment_count                            253
# Name: 14, dtype: object
# 15
# video_id                                     _DwG8fukuj4
# video_title      Conservation of Energy Physics Problems
# upload_date                                   2021-04-06
# view_count                                         81409
# like_count                                          1372
# dislike_count                                         25
# comment_count                                         78
# Name: 15, dtype: object
# 16
# video_id                SsA7rZ8kczM
# video_title      ACT Math Test Prep
# upload_date              2021-04-05
# view_count                    77842
# like_count                     2042
# dislike_count                    28
# comment_count                   257
# Name: 16, dtype: object
# 17
# video_id                            3RwUIP9pMSo
# video_title      Calculus 2 Final Exam Review -
# upload_date                          2021-04-02
# view_count                                69359
# like_count                                 1439
# dislike_count                                12
# comment_count                               122
# Name: 17, dtype: object
# 18
# video_id                                               2KuNzB0cZL4
# video_title      Gibbs Free Energy - Entropy, Enthalpy &amp; Eq...
# upload_date                                             2021-03-30
# view_count                                                  109862
# like_count                                                    1546
# dislike_count                                                   26
# comment_count                                                   55
# Name: 18, dtype: object
# 19
# video_id                                    B_ketdzJtY8
# video_title      Organic Chemistry - Basic Introduction
# upload_date                                  2021-03-29
# view_count                                       496619
# like_count                                         8188
# dislike_count                                       109
# comment_count                                       296
# Name: 19, dtype: object
# 20
# video_id                                               kO-9OajoPZs
# video_title      Ksp - Molar Solubility, Ice Tables, &amp; Comm...
# upload_date                                             2021-03-28
# view_count                                                  100663
# like_count                                                    1411
# dislike_count                                                   24
# comment_count                                                  120
# Name: 20, dtype: object
# 21
# video_id                     3pXALn2ovIE
# video_title      Trigonometric Integrals
# upload_date                   2021-03-26
# view_count                        232677
# like_count                          3744
# dislike_count                         63
# comment_count                        169
# Name: 21, dtype: object
# 22
# video_id                                          hz-fSXifP9w
# video_title      SN2 SN1 E1 E2 Reaction Mechanisms Made Easy!
# upload_date                                        2021-03-26
# view_count                                             145796
# like_count                                               2489
# dislike_count                                              28
# comment_count                                              70
# Name: 22, dtype: object
# 23
# video_id                  sWSLLO3DS1I
# video_title      Integration By Parts
# upload_date                2021-03-25
# view_count                     341545
# like_count                       4987
# dislike_count                      97
# comment_count                     206
# Name: 23, dtype: object
# 24
# video_id                                               RIBeeW1DSZg
# video_title      Static Friction and Kinetic Friction Physics P...
# upload_date                                             2021-02-22
# view_count                                                  186312
# like_count                                                    3087
# dislike_count                                                   47
# comment_count                                                  130
# Name: 24, dtype: object
# 25
# video_id                                               52R61aSWHg0
# video_title      Free Body Diagrams - Tension, Friction, Inclin...
# upload_date                                             2021-02-21
# view_count                                                  125441
# like_count                                                    1934
# dislike_count                                                   37
# comment_count                                                   64
# Name: 25, dtype: object
# 26
# video_id                                               N6IhkTjWrd4
# video_title      Pulley Physics Problem - Finding Acceleration ...
# upload_date                                             2021-02-19
# view_count                                                  180528
# like_count                                                    2559
# dislike_count                                                   68
# comment_count                                                  116
# Name: 26, dtype: object
# 27
# video_id                                               B1bWIrOe0SE
# video_title      Writing Rate Laws of Reaction Mechanisms Using...
# upload_date                                             2021-02-16
# view_count                                                  122618
# like_count                                                    2026
# dislike_count                                                   24
# comment_count                                                  133
# Name: 27, dtype: object
# 28
# video_id                          bNcTt3l3Q8k
# video_title      Le Chatelier&#39;s Principle
# upload_date                        2021-02-13
# view_count                             128099
# like_count                               2880
# dislike_count                              38
# comment_count                             137
# Name: 28, dtype: object
# 29
# video_id                                               kJTCuRSeh6g
# video_title      pH of Weak Acids and Bases - Percent Ionizatio...
# upload_date                                             2021-02-12
# view_count                                                  149610
# like_count                                                    2828
# dislike_count                                                   36
# comment_count                                                  130
# Name: 29, dtype: object
# 30
# video_id                        Ft2_QtXAnh8
# video_title      Linear Equations - Algebra
# upload_date                      2021-02-10
# view_count                           368962
# like_count                             7516
# dislike_count                           149
# comment_count                           364
# Name: 30, dtype: object
# 31
# video_id                                      7DPWeBszNSM
# video_title      How To Solve Linear Equations In Algebra
# upload_date                                    2021-02-09
# view_count                                         105943
# like_count                                           2307
# dislike_count                                          42
# comment_count                                         139
# Name: 31, dtype: object
# 32
# video_id                       KoZ61FujkRk
# video_title      Electric Potential Energy
# upload_date                     2021-01-30
# view_count                           75737
# like_count                            1340
# dislike_count                           13
# comment_count                           63
# Name: 32, dtype: object
# 33
# video_id                                        jt7p-mCC0ng
# video_title      Evaluating Inverse Trigonometric Functions
# upload_date                                      2021-01-30
# view_count                                           229361
# like_count                                             3980
# dislike_count                                            68
# comment_count                                           143
# Name: 33, dtype: object
# 34
# video_id                LzKMQByFSLc
# video_title      Electric Potential
# upload_date              2021-01-29
# view_count                   160974
# like_count                     2958
# dislike_count                    35
# comment_count                   128
# Name: 34, dtype: object
# 35
# video_id                                               V9RLc9EX1so
# video_title      Electric Field Due To Point Charges - Physics ...
# upload_date                                             2021-01-27
# view_count                                                  273712
# like_count                                                    4434
# dislike_count                                                   55
# comment_count                                                  168
# Name: 35, dtype: object
# 36
# video_id                                               0g3339ciUls
# video_title      Raoult&#39;s Law - How To Calculate The Vapor ...
# upload_date                                             2021-01-23
# view_count                                                   82706
# like_count                                                    1123
# dislike_count                                                   14
# comment_count                                                   54
# Name: 36, dtype: object
# 37
# video_id                                               JQBRzsPhw2w
# video_title      Logic Gates, Truth Tables, Boolean Algebra   A...
# upload_date                                             2021-01-22
# view_count                                                  469295
# like_count                                                    8198
# dislike_count                                                  128
# comment_count                                                  282
# Name: 37, dtype: object
# 38
# video_id                                               zg9N2gAf6a4
# video_title      Convergence and Divergence - Introduction to S...
# upload_date                                             2021-01-20
# view_count                                                  186447
# like_count                                                    3259
# dislike_count                                                   57
# comment_count                                                  103
# Name: 38, dtype: object
# 39
# video_id                                               a5x4lwnvHM0
# video_title      How To Graph Polynomial Functions Using End Be...
# upload_date                                             2021-01-17
# view_count                                                  286714
# like_count                                                    5146
# dislike_count                                                   86
# comment_count                                                  183
# Name: 39, dtype: object
# 40
# video_id                                    _39hCnqbNXM
# video_title      Relative Velocity - Basic Introduction
# upload_date                                  2021-01-15
# view_count                                        92360
# like_count                                         1816
# dislike_count                                        18
# comment_count                                        88
# Name: 40, dtype: object
# 41
# video_id                                               FFDMzbrEXaE
# video_title      Number Systems Introduction - Decimal, Binary,...
# upload_date                                             2021-01-15
# view_count                                                  303113
# like_count                                                    6342
# dislike_count                                                  124
# comment_count                                                  243
# Name: 41, dtype: object
# 42
# video_id                                               HCWwRh5CXYU
# video_title      Unit Cell Chemistry   Simple Cubic, Body Cente...
# upload_date                                             2021-01-14
# view_count                                                  147385
# like_count                                                    2459
# dislike_count                                                   51
# comment_count                                                   92
# Name: 42, dtype: object
# 43
# video_id                                               tfItlGfPHyo
# video_title      How To Solve Projectile Motion Problems In Phy...
# upload_date                                             2021-01-14
# view_count                                                  230277
# like_count                                                    3510
# dislike_count                                                   63
# comment_count                                                  127
# Name: 43, dtype: object
# 44
# video_id                                               pdJeQUd2g_4
# video_title      Hybridization of Atomic Orbitals - Sigma &amp;...
# upload_date                                             2021-01-12
# view_count                                                  477533
# like_count                                                    7972
# dislike_count                                                  219
# comment_count                                                  190
# Name: 44, dtype: object
# 45
# video_id                                Rf05H8ogHLg
# video_title      Verifying Trigonometric Identities
# upload_date                              2021-01-10
# view_count                                   268610
# like_count                                     4821
# dislike_count                                    72
# comment_count                                   270
# Name: 45, dtype: object
# 46
# video_id                                     GiCojsAWRj0
# video_title      Calculus 1 Review -  Basic Introduction
# upload_date                                   2021-01-09
# view_count                                        208749
# like_count                                          3438
# dislike_count                                         36
# comment_count                                        118
# Name: 46, dtype: object
# 47
# video_id                                              Vqx9a2aU99c
# video_title      Valence Bond Theory &amp; Hybrid Atomic Orbitals
# upload_date                                            2021-01-07
# view_count                                                 140688
# like_count                                                   2667
# dislike_count                                                  30
# comment_count                                                  69
# Name: 47, dtype: object
# 48
# video_id                                     qMXPnfx2MQM
# video_title      Volumes Using Cross Sections - Calculus
# upload_date                                   2021-01-07
# view_count                                         68027
# like_count                                           967
# dislike_count                                         10
# comment_count                                         59
# Name: 48, dtype: object
# 49
# video_id                                 D5sT1br9soI
# video_title      Shell Method - Volume of Revolution
# upload_date                               2021-01-06
# view_count                                    157182
# like_count                                      2146
# dislike_count                                     27
# comment_count                                     98
# Name: 49, dtype: object

# %%
conn.commit()

# %%
new_videos_df
# Out:
#        video_id                                        video_title  \
# 0   rUICJO4qwms  How To Grow Your YouTube Channel - 5 Tips For ...
# 1   wbBY2tTqXDA                            Relations and Functions
# 2   dHjWVlfNraM              Kinematics In One Dimension - Physics
# 3   OqsOIp5UuME                               Resonance Structures
# 4   zRKZ0-kOUZM  Geometric Series and Geometric Sequences - Bas...
# 5   XZJdyPkCxuE  Arithmetic Sequences and Arithmetic Series - B...
# 6   J6TnZxUUzqU  Complex Numbers In Polar - De Moivre&#39;s The...
# 7   KYgmOTLbuqE  Finding The Focus and Directrix of a Parabola ...
# 8   OPSCKXXvWiM  Writing Equations of Ellipses In Standard Form...
# 9   QKkdYW77xNI                       Partial Fraction Decomposion
# 10  xaCPDMEkbig                                    Antiderivatives
# 11  sdYdnpYn-1o              How To Integrate Using U-Substitution
# 12  jO4lwddfeDA                       How To Graph Polar Equations
# 13  Tmdrjs9xufc                       Transformations of Functions
# 14  CwkhvFlNFp0                        Physics 1 Final Exam Review
# 15  _DwG8fukuj4            Conservation of Energy Physics Problems
# 16  SsA7rZ8kczM                                 ACT Math Test Prep
# 17  3RwUIP9pMSo                     Calculus 2 Final Exam Review -
# 18  2KuNzB0cZL4  Gibbs Free Energy - Entropy, Enthalpy &amp; Eq...
# 19  B_ketdzJtY8             Organic Chemistry - Basic Introduction
# 20  kO-9OajoPZs  Ksp - Molar Solubility, Ice Tables, &amp; Comm...
# 21  3pXALn2ovIE                            Trigonometric Integrals
# 22  hz-fSXifP9w       SN2 SN1 E1 E2 Reaction Mechanisms Made Easy!
# 23  sWSLLO3DS1I                               Integration By Parts
# 24  RIBeeW1DSZg  Static Friction and Kinetic Friction Physics P...
# 25  52R61aSWHg0  Free Body Diagrams - Tension, Friction, Inclin...
# 26  N6IhkTjWrd4  Pulley Physics Problem - Finding Acceleration ...
# 27  B1bWIrOe0SE  Writing Rate Laws of Reaction Mechanisms Using...
# 28  bNcTt3l3Q8k                       Le Chatelier&#39;s Principle
# 29  kJTCuRSeh6g  pH of Weak Acids and Bases - Percent Ionizatio...
# 30  Ft2_QtXAnh8                         Linear Equations - Algebra
# 31  7DPWeBszNSM           How To Solve Linear Equations In Algebra
# 32  KoZ61FujkRk                          Electric Potential Energy
# 33  jt7p-mCC0ng         Evaluating Inverse Trigonometric Functions
# 34  LzKMQByFSLc                                 Electric Potential
# 35  V9RLc9EX1so  Electric Field Due To Point Charges - Physics ...
# 36  0g3339ciUls  Raoult&#39;s Law - How To Calculate The Vapor ...
# 37  JQBRzsPhw2w  Logic Gates, Truth Tables, Boolean Algebra   A...
# 38  zg9N2gAf6a4  Convergence and Divergence - Introduction to S...
# 39  a5x4lwnvHM0  How To Graph Polynomial Functions Using End Be...
# 40  _39hCnqbNXM             Relative Velocity - Basic Introduction
# 41  FFDMzbrEXaE  Number Systems Introduction - Decimal, Binary,...
# 42  HCWwRh5CXYU  Unit Cell Chemistry   Simple Cubic, Body Cente...
# 43  tfItlGfPHyo  How To Solve Projectile Motion Problems In Phy...
# 44  pdJeQUd2g_4  Hybridization of Atomic Orbitals - Sigma &amp;...
# 45  Rf05H8ogHLg                 Verifying Trigonometric Identities
# 46  GiCojsAWRj0            Calculus 1 Review -  Basic Introduction
# 47  Vqx9a2aU99c   Valence Bond Theory &amp; Hybrid Atomic Orbitals
# 48  qMXPnfx2MQM            Volumes Using Cross Sections - Calculus
# 49  D5sT1br9soI                Shell Method - Volume of Revolution
#
#    upload_date view_count like_count dislike_count comment_count
# 0   2021-10-26      93860       2879            34           447
# 1   2021-08-25      67543       1863            21           128
# 2   2021-05-31     212740       4013            57           161
# 3   2021-05-24     101855       1500            34            67
# 4   2021-05-16     175094       3125            77           109
# 5   2021-05-13     287783       5852            87           192
# 6   2021-05-10     111724       1938            38           110
# 7   2021-05-02     203797       3381            67           144
# 8   2021-04-29     149027       2595            52            97
# 9   2021-04-23     272121       4359            97           133
# 10  2021-04-21     138979       2956            25           127
# 11  2021-04-19     342628       5881            72           256
# 12  2021-04-17      84510       1612            28            68
# 13  2021-04-16     104124       2279            35            76
# 14  2021-04-07     121891       3196            22           253
# 15  2021-04-06      81409       1372            25            78
# 16  2021-04-05      77842       2042            28           257
# 17  2021-04-02      69359       1439            12           122
# 18  2021-03-30     109862       1546            26            55
# 19  2021-03-29     496619       8188           109           296
# 20  2021-03-28     100663       1411            24           120
# 21  2021-03-26     232677       3744            63           169
# 22  2021-03-26     145796       2489            28            70
# 23  2021-03-25     341545       4987            97           206
# 24  2021-02-22     186312       3087            47           130
# 25  2021-02-21     125441       1934            37            64
# 26  2021-02-19     180528       2559            68           116
# 27  2021-02-16     122618       2026            24           133
# 28  2021-02-13     128099       2880            38           137
# 29  2021-02-12     149610       2828            36           130
# 30  2021-02-10     368962       7516           149           364
# 31  2021-02-09     105943       2307            42           139
# 32  2021-01-30      75737       1340            13            63
# 33  2021-01-30     229361       3980            68           143
# 34  2021-01-29     160974       2958            35           128
# 35  2021-01-27     273712       4434            55           168
# 36  2021-01-23      82706       1123            14            54
# 37  2021-01-22     469295       8198           128           282
# 38  2021-01-20     186447       3259            57           103
# 39  2021-01-17     286714       5146            86           183
# 40  2021-01-15      92360       1816            18            88
# 41  2021-01-15     303113       6342           124           243
# 42  2021-01-14     147385       2459            51            92
# 43  2021-01-14     230277       3510            63           127
# 44  2021-01-12     477533       7972           219           190
# 45  2021-01-10     268610       4821            72           270
# 46  2021-01-09     208749       3438            36           118
# 47  2021-01-07     140688       2667            30            69
# 48  2021-01-07      68027        967            10            59
# 49  2021-01-06     157182       2146            27            98

# %%
append_data_to_db(curr, new_videos_df)
